# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
gender_groups = ["Other / Non-Disclosed", "Female", "Male"]
purchase_value = [4.56, 4.47, 4.07]
x_axis = np.arange(len(purchase_value))

# %%
plt.bar(x_axis, total_value, color = 'green', align = 'center')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 8 artists>

# %%
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, gender_groups)
# Out:
# ([<matplotlib.axis.XTick at 0x22fe81520b8>,
# ...
#  [Text(-1.0, 0, '<10'),
#   Text(0.0, 0, '10-14'),
#   Text(1.0, 0, '15-19'),
#   Text(2.0, 0, '20-24'),
#   Text(3.0, 0, '25-29'),
#   Text(4.0, 0, '30-34'),
#   Text(5.0, 0, '35-40'),
#   Text(6.0, 0, '40+')])

# %%
plt.title("Average Total Purchase")
plt.ylabel("Dollars Spent")
plt.xlabel("Age Group")
# Out:
# Text(0.5, 23.52222222222222, 'Age Group')

# %%
plt.savefig("PurchaseValue.png")
